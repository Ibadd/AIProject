# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibadd/AIProject/blob/main/Ai_Image_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 
from google.colab.patches import cv2_imshow

# %%
# membaca image
image = cv2.imread("001.jpg")

# %%
print(image)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [253 253 253]
#   [253 253 253]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [253 255 253]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [253 253 253]
#   [251 253 251]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [253 253 253]
#   [251 251 251]
#   [251 251 249]]]

# %%
# menampilkan image
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x1200 at 0x7FBD62BB5E90>

# %%
print(image.shape)
# Out:
# (1200, 1600, 3)

# %%
# mengakeses nilai di pixel x=100, y=20
(b, g, r) = image[20, 100]
print("blue =" ,b)
print("green =" ,g)
print("red =" ,r)
# Out:
# blue = 255
# green = 255
# red = 255

# %%
# crop image
im_crop = image[100:660, 100:300]

cv2_imshow(im_crop)
cv2.waitKey(0)
cv2.destroyAllWindows()
print(im_crop.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=200x560 at 0x7FBD62B58310>
# (560, 200, 3)

# %%
# mengcopy image
cp_image = image.copy()
print(cp_image.shape)
# Out:
# (1200, 1600, 3)

# %%
# mengubah nilai pixel
cp_image[300:350, 170:300] = (255, 255, 255)

cv2_imshow(cp_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1600x1200 at 0x7FBD62AE4290>

# %%
# resize image (ignore aspect ratio)
im_resized = cv2.resize(image, (400,400))

cv2_imshow(im_resized)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FBD62BB5650>

# %%
# resize image (Mempertahankan aspek ratio)
r = 400/image.shape[1]
dim = (400, int(image.shape[0]*r))
im_resized = cv2.resize(image, dim)

cv2_imshow(im_resized)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7FBD62AE47D0>

# %%
# rotating an image
(h, w) = image.shape[:2]
center = (w/2, h/2)

M = cv2.getRotationMatrix2D(center, 180, 1.0)
rotate = cv2.warpAffine(image, M, (w,h))

cv2_imshow(rotate)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1600x1200 at 0x7FBD62B4C350>

# %%
# menyimpan Image
cv2.imwrite("rotate.png", rotate)
# Out:
# True

# %%
#adjust image contrast
import numpy as np
im_adjusted = cv2.addWeighted(im_resized, 1.5, np.zeros(im_resized.shape, im_resized.dtype), 0, -100)


cv2_imshow(im_resized)
cv2_imshow(im_adjusted)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7FBD62B06310>
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7FBD62B06410>

# %%
# detect edges
im_edges = cv2.Canny(im_resized, 100, 200)

cv2_imshow(im_resized)
cv2_imshow(im_edges)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7FBD62BB5E50>
# <PIL.Image.Image image mode=L size=400x300 at 0x7FBD62BB5CD0>

# %%
# covert image to greyscale
im_gray = cv2.cvtColor(im_resized, cv2.COLOR_BGR2GRAY)

cv2_imshow(im_resized)
cv2_imshow(im_gray)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7FBD62B06AD0>
# <PIL.Image.Image image mode=L size=400x300 at 0x7FBD62AEEA50>

# %%
#get All file in folder
import glob

imdir = 'dataset/elephant/'
ext = ['png', 'jpg', 'gif']    # Add image formats here

files = []
[files.extend(glob.glob(imdir + '*.' + e)) for e in ext]
  
images = [cv2.imread(file) for file in files]
  
# adjust contrast to all of them nd save to different location
i = 1
for img in images:
    im_adjusted = cv2.addWeighted(img, 1.5, np.zeros(img.shape, img.dtype), 0, -100)
    im_name = "dataset/elephant_contrast/" + str(i) + ".jpg"
    cv2.imwrite(im_name, im_adjusted)
    i+=1

# %%
def twice(function): 
  return lambda x: function(function(x))  
def f(x): 
  	return x + 3 
g = twice(f)
print (g(7))
# Out:
# 13

# %%
my_list = [1, 2, 3, 4, 5] 

sum = 0 
for x in my_list: 
	sum += x 
print(sum)
# Out:
# 15
